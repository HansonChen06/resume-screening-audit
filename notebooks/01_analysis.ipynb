# %% [markdown]
# # Preregistered paired analysis
# The source of truth is `src/analysis.py`; this notebook is a review surface.

# %%
import pandas as pd
pd.read_csv('../data/processed/results.csv')
