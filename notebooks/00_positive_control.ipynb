# %% [markdown]
# # Positive and negative controls
# Generated outputs are read from the deterministic pipeline; see `src/experiment.py`.

# %%
import json
json.load(open('../data/processed/controls.json'))
